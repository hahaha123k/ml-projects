# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/NSE-TATAGLOBAL.csv'
dataset_train = pd.read_csv(url)
training_set = dataset_train.iloc[:, 1:2].values

# %%
dataset_train
# Out:
#             Date    Open    High     Low    Last   Close  \
# 0     2018-09-28  234.05  235.95  230.20  233.50  233.75
# 1     2018-09-27  234.55  236.80  231.10  233.80  233.25
# 2     2018-09-26  240.00  240.00  232.50  235.00  234.25
# 3     2018-09-25  233.30  236.75  232.00  236.25  236.10
# 4     2018-09-24  233.55  239.20  230.75  234.00  233.30
# ...          ...     ...     ...     ...     ...     ...
# 2030  2010-07-27  117.60  119.50  112.00  118.80  118.65
# 2031  2010-07-26  120.10  121.00  117.10  117.10  117.60
# 2032  2010-07-23  121.80  121.95  120.25  120.35  120.65
# 2033  2010-07-22  120.30  122.00  120.25  120.75  120.90
# 2034  2010-07-21  122.10  123.00  121.05  121.10  121.55
#
#       Total Trade Quantity  Turnover (Lacs)
# 0                  3069914          7162.35
# 1                  5082859         11859.95
# 2                  2240909          5248.60
# 3                  2349368          5503.90
# 4                  3423509          7999.55
# ...                    ...              ...
# 2030                586100           694.98
# 2031                658440           780.01
# 2032                281312           340.31
# 2033                293312           355.17
# 2034                658666           803.56
#
# [2035 rows x 8 columns]

# %%
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60, 2035):
  X_train.append(training_set_scaled[i-60:i, 0])
  y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM
from keras.layers import Dropout
from keras.layers import Dense

# %%
model = Sequential()
model.add(LSTM(units=50,return_sequences=True,input_shape=(X_train.shape[1], 1)))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50,return_sequences=True))
model.add(Dropout(0.2))
model.add(LSTM(units=50))
model.add(Dropout(0.2))
model.add(Dense(units=1))
model.compile(optimizer='adam',loss='mean_squared_error')
model.fit(X_train,y_train,epochs=50,batch_size=32)
# Out:
# Epoch 1/50
# 62/62 [==============================] - 29s 253ms/step - loss: 0.0099
# Epoch 2/50
# 62/62 [==============================] - 8s 129ms/step - loss: 0.0031
# Epoch 3/50
# 62/62 [==============================] - 8s 124ms/step - loss: 0.0028
# Epoch 4/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0026
# Epoch 5/50
# 62/62 [==============================] - 8s 123ms/step - loss: 0.0024
# Epoch 6/50
# 62/62 [==============================] - 8s 123ms/step - loss: 0.0021
# Epoch 7/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0021
# Epoch 8/50
# 62/62 [==============================] - 8s 129ms/step - loss: 0.0020
# Epoch 9/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0018
# Epoch 10/50
# 62/62 [==============================] - 8s 128ms/step - loss: 0.0020
# Epoch 11/50
# 62/62 [==============================] - 8s 124ms/step - loss: 0.0019
# Epoch 12/50
# 62/62 [==============================] - 8s 127ms/step - loss: 0.0021
# Epoch 13/50
# 62/62 [==============================] - 8s 137ms/step - loss: 0.0017
# Epoch 14/50
# 62/62 [==============================] - 9s 148ms/step - loss: 0.0018
# Epoch 15/50
# 62/62 [==============================] - 8s 122ms/step - loss: 0.0016
# Epoch 16/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0015
# Epoch 17/50
# 62/62 [==============================] - 8s 127ms/step - loss: 0.0017
# Epoch 18/50
# 62/62 [==============================] - 8s 128ms/step - loss: 0.0016
# Epoch 19/50
# 62/62 [==============================] - 8s 130ms/step - loss: 0.0016
# Epoch 20/50
# 62/62 [==============================] - 8s 132ms/step - loss: 0.0013
# Epoch 21/50
# 62/62 [==============================] - 8s 130ms/step - loss: 0.0013
# Epoch 22/50
# 62/62 [==============================] - 8s 134ms/step - loss: 0.0012
# Epoch 23/50
# 62/62 [==============================] - 8s 127ms/step - loss: 0.0015
# Epoch 24/50
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0013
# Epoch 25/50
# 62/62 [==============================] - 7s 120ms/step - loss: 0.0012
# Epoch 26/50
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0012
# Epoch 27/50
# 62/62 [==============================] - 7s 118ms/step - loss: 0.0011
# Epoch 28/50
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0016
# Epoch 29/50
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0012
# Epoch 30/50
# 62/62 [==============================] - 7s 121ms/step - loss: 0.0012
# Epoch 31/50
# 62/62 [==============================] - 7s 119ms/step - loss: 0.0011
# Epoch 32/50
# 62/62 [==============================] - 7s 120ms/step - loss: 9.9419e-04
# Epoch 33/50
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0011
# Epoch 34/50
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0010
# Epoch 35/50
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0011
# Epoch 36/50
# 62/62 [==============================] - 7s 120ms/step - loss: 9.2683e-04
# Epoch 37/50
# 62/62 [==============================] - 9s 143ms/step - loss: 0.0010
# Epoch 38/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0011
# Epoch 39/50
# 62/62 [==============================] - 8s 126ms/step - loss: 0.0011
# Epoch 40/50
# 62/62 [==============================] - 8s 124ms/step - loss: 0.0011
# Epoch 41/50
# 62/62 [==============================] - 8s 122ms/step - loss: 9.4833e-04
# Epoch 42/50
# 62/62 [==============================] - 8s 125ms/step - loss: 9.0466e-04
# Epoch 43/50
# 62/62 [==============================] - 8s 122ms/step - loss: 8.9319e-04
# Epoch 44/50
# 62/62 [==============================] - 8s 124ms/step - loss: 8.9694e-04
# Epoch 45/50
# 62/62 [==============================] - 8s 121ms/step - loss: 0.0010
# Epoch 46/50
# 62/62 [==============================] - 8s 123ms/step - loss: 9.4010e-04
# Epoch 47/50
# 62/62 [==============================] - 8s 122ms/step - loss: 9.2866e-04
# Epoch 48/50
# 62/62 [==============================] - 7s 120ms/step - loss: 8.7529e-04
# Epoch 49/50
# 62/62 [==============================] - 7s 120ms/step - loss: 8.6689e-04
# Epoch 50/50
# 62/62 [==============================] - 7s 121ms/step - loss: 7.6235e-04

# %%
#Making Predictions on the Test Set
url = 'https://raw.githubusercontent.com/mwitiderrick/stockprice/master/tatatest.csv'
dataset_test = pd.read_csv(url)
real_stock_price = dataset_test.iloc[:, 1:2].values

# %%
dataset_total = pd.concat((dataset_train['Open'], dataset_test['Open']), axis = 0)
inputs = dataset_total[len(dataset_total) - len(dataset_test) - 60:].values
inputs = inputs.reshape(-1,1)
inputs = sc.transform(inputs)
X_test = []
for i in range(60, 76):
  X_test.append(inputs[i-60:i, 0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))
predicted_stock_price = model.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)
# Out:
# 1/1 [==============================] - 2s 2s/step

# %%
plt.plot(real_stock_price, color = 'black', label = 'TATA Stock Price')
plt.plot(predicted_stock_price, color = 'green', label = 'Predicted TATA Stock Price')
plt.title('TATA Stock Price Prediction')
plt.xlabel('Time')
plt.ylabel('TATA Stock Price')
plt.legend()
plt.show()
